# %%
import albumentations as A
import random
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

def visualize(image):
    plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(image)

folder_names = ["Apel", 
        "Ayam_Goreng", 
        "Bakso", 
        "Bakwan", 
        "Batagor", 
        "Beberuk", 
        "Bubur", 
        "Burger", 
        "Cakwe", 
        "Capcay", 
        "Crepes", 
        "Donat", 
        "EsKrim", 
        "Gudeg", 
        "Gulai_Ikan", 
        "Ikan_Goreng", 
        "Jeruk",
        "Kebab",
        "Kentang_Goreng", 
        "Kerak_Telor", 
        "Nasi_Kuning",
        "Nasi_Pecel",
        "Papeda",
        "Rendang", 
        "Tahu_Sumedang"]
   

for name in folder_names:
    for i in range(2, 4):
        main_folder = f"E:/Dataset/edited_dataset/buangan/train/{name}"
        folder_destination = f"E:/Dataset/edited_dataset/buangan/train/{name} - Copy ({i})"
        for filename in os.listdir(main_folder):
            file_path = os.path.join(main_folder, filename)
            image = cv2.imread(file_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            transform = A.Compose([
                A.HorizontalFlip(p=0.5),
                A.RandomBrightnessContrast(p=0.2),
                A.Blur(blur_limit=3),
                A.ShiftScaleRotate(p=0.3),
                A.RandomRotate90(),
            ])
            augmented_image = transform(image=image)['image']
            augmented_image_bgr = cv2.cvtColor(augmented_image, cv2.COLOR_RGB2BGR)
            cv2.imwrite(os.path.join(folder_destination, filename), augmented_image_bgr)
        print("Successfully augmented all files")
# Out:
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files
# Successfully augmented all files

# %%
import os
folder_names = ["Apel", 
        "Ayam_Goreng", 
        "Bakso", 
        "Bakwan", 
        "Batagor", 
        "Beberuk", 
        "Bubur", 
        "Burger", 
        "Cakwe", 
        "Capcay", 
        "Crepes", 
        "Donat", 
        "EsKrim", 
        "Gudeg", 
        "Gulai_Ikan", 
        "Ikan_Goreng", 
        "Jeruk",
        "Kebab",
        "Kentang_Goreng", 
        "Kerak_Telor", 
        "Nasi_Kuning",
        "Nasi_Pecel",
        "Papeda",
        "Rendang", 
        "Tahu_Sumedang"]
for new_name in folder_names:

    base_dir = f'C:/Users/User/Documents/VS/python/capstone/ML-Capstone/val_data/val/{new_name}'
    file_list = os.listdir(base_dir)
    for i, filename in enumerate(file_list):
        if filename.endswith('.jpg'):
            name, ext = os.path.splitext(filename)
            new_filename = f'{new_name.lower()}{300 + i}{ext}'
            os.rename(os.path.join(base_dir, filename), os.path.join(base_dir, new_filename))
    print("Successfully renamed all files")
# Out:
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
# Successfully renamed all files
